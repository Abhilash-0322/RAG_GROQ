# %%
import pandas as pd

df=pd.read_csv("D:/codespace/ML/NYD/Vedanta_Datasets/Bhagwad_Gita/Bhagwad_Gita_Verses_English_Questions.csv")

# %%
df
# Out:
#      chapter  verse     speaker  \
# 0          1      1  धृतराष्ट्र
# 1          1      2       सञ्जय
# 2          1      3       सञ्जय
# 3          1      4       सञ्जय
# 4          1      5       सञ्जय
# ..       ...    ...         ...
# 695       18     74       सञ्जय
# 696       18     75       सञ्जय
# 697       18     76       सञ्जय
# 698       18     77       सञ्जय
# 699       18     78       सञ्जय
#
#                                               sanskrit  \
# 0    धर्मक्षेत्रे कुरुक्षेत्रे समवेता युयुत्सवः| मा...
# 1    दृष्ट्वा तु पाण्डवानीकं व्यूढं दुर्योधनस्तदा| ...
# 2    पश्यैतां पाण्डुपुत्राणामाचार्य महतीं चमूम्| व्...
# 3    अत्र शूरा महेष्वासा भीमार्जुनसमा युधि| युयुधान...
# 4    धृष्टकेतुश्चेकितानः काशिराजश्च वीर्यवान्| पुरु...
# ..                                                 ...
# 695  इत्यहं वासुदेवस्य पार्थस्य च महात्मनः| संवादमि...
# 696  व्यासप्रसादाच्छ्रुतवानेतद्गुह्यमहं परम्| योगं ...
# 697  राजन्संस्मृत्य संस्मृत्य संवादमिममद्भुतम्| केश...
# ...

# %%
df_new=df[['question','translation','verse','chapter']]

# %%
df_new
# Out:
#                                               question  \
# 0                             How does the Gita start?
# 1    In the Mahabharata war, whom did Duryodhana fi...
# 2       What did Duryodhana say to his teacher, Drona?
# 3    Which warriors from the Pandava army did Duryo...
# 4    Who was the king from Kashi who fought in the ...
# ..                                                 ...
# 695  Did Sanjaya have any physical signs of emotion...
# 696   By whose grace did Sanjaya get to hear the Gita?
# 697     Was Sanjaya happy after hearing the full Gita?
# 698  Why was Sanjaya happy after hearing the full G...
# 699            What did Sanjaya predict about the war?
#
#                                            translation  verse  chapter
# 0    Dhritarashtra said, "What did my people and th...      1        1
# 1    Sanjaya said: Having seen the army of the Pand...      2        1
# 2    Behold, O Teacher! This mighty army of the son...      3        1
# ...

# %%
df_new.to_csv('bhagwatgita_queeng.csv',index=False)
